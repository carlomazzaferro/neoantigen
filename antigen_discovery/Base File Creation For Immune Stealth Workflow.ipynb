# %% [markdown]
# # Conservation Analysis and Epitope Prediction
#
#
# #### Author: C. Mazzaferro, K. Fisch
# #### Email: cmazzafe@ucsd.edu
# #### Date: October 2016
#
# ## Outline of Notebook
# <a id = "toc"></a>
# 1. <a href = "#background">Background</a>
# 2. <a href = "#Cons">High Affinity Binding Prediction </a>
#     * <a href = "#Agg">Data Aggregation</a>
#     * <a href = "#Sim">Similarty Score Calculation</a>
#     * <a href = "#Plot">Visualize</a>

# %% [markdown]
# ### Files of interest
# From a simple fasta file containing the proteins of interest, this workflow will create:
#
# 1. Binding affinity prediction xls files for the given allele, nmer combinations. Default set to all allele supertypes and [8, 9, 10, 11] nmers
# 2. Csv file containing all high binding affinity peptides. Threshold can be set to a customized level (either by setting it to Medium or setting it by affinity score. See [CBS's prediction services](http://www.cbs.dtu.dk/services/), in particular [netMHC](http://www.cbs.dtu.dk/services/NetMHC/) for more specific information.
# 3. Fasta files containing swap data: for each high affinity binding peptide, find every peptide that results from swapping one single AA from it. These fasta files are then fed into netMHC again and their binding affinity determined again.
# 4. Csv files for each fasta file with the swapped peptide binding prediction.
#
# Caveats: netMHC local install must be in the system's path.

# %%
import importlib
from nepitope import net_MHC_interface
from nepitope import mhc_utils
from nepitope import pep_utils
import pandas

project_location = '/Users/carlomazzaferro/Desktop/New_General/'
fasta_file = '/Users/carlomazzaferro/Desktop/New_General/fasta_base_new_prots.fasta'
net_mhc_path = '/Users/carlomazzaferro/Desktop/BINF_Tools/netMHC-4.0/netMHC'

"""
Default Parameters:

all_alleles = ['HLA-A0101','HLA-A0201','HLA-A0301','HLA-A2402','HLA-A2601',
               'HLA-B0702','HLA-B0801','HLA-B2705','HLA-B3901','HLA-B4001','HLA-B5801','HLA-B1501']

nmer_list = [8,9,10,11]

"""


net_mhc = net_MHC_interface.netMHCComand(net_mhc_path, fasta_file)

# %% [markdown]
# ### <a id = "Cons"></a>
# # MHC Binding Affinity Prediction
# ### Ran on netMHCcons for n-mers of 8, 9, 10, 11 amino acids and for the 12 allele supertype families
#
# Run for each protein sequence retrieved from reference paper.

# %%
net_mhc.create_text_command()
# Out:
# 'netMHC commands written to run_netMHC.txt located at /Users/carlomazzaferro/Desktop/New_General/mhc_preds_fasta_base_new_prots'

# %%
net_mhc.run_netMHC()
# Out:
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/mhc_preds_fasta_base_new_prots

# %%
### Load predictions 
import importlib
importlib.reload(mhc_utils)
pred_loc = '/Users/carlomazzaferro/Desktop/New_General/mhc_preds_fasta_base_new_prots/'
agg = mhc_utils.FileConsolidation(pred_loc, fasta_file)

# %%
csv_dir = '/Users/carlomazzaferro/Desktop/New_General/high_affinity_peps.csv'
high_aa_df = agg.get_all_high_affinity_from_batch(csv_out=True, csv_dir=csv_dir)
# Out:
# /Users/carlomazzaferro/anaconda/envs/py35/lib/python3.5/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
high_aa_df.head()
# Out:
#        Pos     Peptide    nM  Rank                               ID  \
# 1003  1003  LESEFVYGDY  33.5  0.06                 S__pyogenes_Cas9
# 2388  1029  YSTDILGNLY   3.7  0.01       Staphylococcus_aureus_Cas9
# 2389  1030  STDILGNLYE  47.1  0.08       Staphylococcus_aureus_Cas9
# 2608   205  QITDEFINRY  44.0  0.08     S_CRISPR_1_thermophilus_Cas9
# 7793  1102  VRTDVLGNKY  38.1  0.07  Streptococcus_pasteurianus_Cas9
#
#          Allele Affinity Level  n-mer
# 1003  HLA-A0101           High     10
# 2388  HLA-A0101           High     10
# 2389  HLA-A0101           High     10
# 2608  HLA-A0101           High     10
# 7793  HLA-A0101           High     10

# %% [markdown]
# # Swap Files

# %%
high_aa_df = pandas.read_csv(csv_dir) 
high_aa_df.head()
# Out:
#    Unnamed: 0   Pos     Peptide    nM  Rank                               ID  \
# 0        1003  1003  LESEFVYGDY  33.5  0.06                 S__pyogenes_Cas9
# 1        2388  1029  YSTDILGNLY   3.7  0.01       Staphylococcus_aureus_Cas9
# 2        2389  1030  STDILGNLYE  47.1  0.08       Staphylococcus_aureus_Cas9
# 3        2608   205  QITDEFINRY  44.0  0.08     S_CRISPR_1_thermophilus_Cas9
# 4        7793  1102  VRTDVLGNKY  38.1  0.07  Streptococcus_pasteurianus_Cas9
#
#       Allele Affinity Level  n-mer
# 0  HLA-A0101           High     10
# 1  HLA-A0101           High     10
# 2  HLA-A0101           High     10
# 3  HLA-A0101           High     10
# 4  HLA-A0101           High     10

# %%
from nepitope import peptide_utilities
importlib.reload(peptide_utilities)
fasta_files_dir = '/Users/carlomazzaferro/Desktop/New_General/swaps/'

swap = peptide_utilities.Swaps(high_aa_df, fasta_files_dir, net_mhc_path, proteins=['S__pyogenes_Cas9'] )

# %%
cmd = swap.find_swaps_write_to_fasta()
# Out:
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LESEFVYGDY_Pos_1003_ID_S--pyogenes-Cas9_Allele_HLA-A0101_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_NGLFGNLIAL_Pos_234_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AILLSDILRV_Pos_298_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_ILTFRIPYYV_Pos_442_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_HSLLYEYFTV_Pos_510_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YLQNGRDMYV_Pos_814_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YLNAVVGTAL_Pos_987_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KLPKYSLFEL_Pos_1196_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_HYLDEIIEQI_Pos_1263_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KAILSARLSK_Pos_208_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KLNREDLLRK_Pos_391_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KVLPKHSLLY_Pos_505_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SLGTYHDLLK_Pos_589_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KTYAHLFDDK_Pos_636_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_TIMERSSFEK_Pos_1166_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_MLASAGELQK_Pos_1212_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_FLYLASHYEK_Pos_1234_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_TNLGAPAAFK_Pos_1315_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_EEVVKKMKNY_Pos_872_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_EFVYGDYKVY_Pos_1006_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_DEIIEQISEF_Pos_1266_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_EIIEQISEFS_Pos_1267_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_IPHQIHLGEL_Pos_409_ID_S--pyogenes-Cas9_Allele_HLA-B0702_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_HMIKFRGHFL_Pos_159_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RLIYLALAHM_Pos_151_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AHMIKFRGHF_Pos_158_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KLFIQLVQTY_Pos_182_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_ALSLGLTPNF_Pos_242_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SLLYEYFTVY_Pos_511_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KQSGKTILDF_Pos_672_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_QLIHDDSLTF_Pos_694_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LQNEKLYLYY_Pos_805_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LIHQSITGLY_Pos_1346_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRYTRRKNRI_Pos_69_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRLENLIAQL_Pos_219_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRQEDFYPFL_Pos_423_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_NSRFAWMTRK_Pos_458_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SRFAWMTRKS_Pos_459_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRRYTGWGRL_Pos_652_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRYTGWGRLS_Pos_653_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_WRQLLNAKLI_Pos_882_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KRMLASAGEL_Pos_1210_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YEYFTVYNEL_Pos_514_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_GVEDRFNASL_Pos_581_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_REQAENIIHL_Pos_1302_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AENIIHLFTL_Pos_1305_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_VSDFRKDFQFY_Pos_962_ID_S--pyogenes-Cas9_Allele_HLA-A0101_nmer_11
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KVYDVRKMIAK_Pos_1013_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_11
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRLENLIAQLP_Pos_219_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_11
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LLYEYFTV_Pos_512_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_8
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_MIKFRGHF_Pos_160_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_8
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRYTGWGR_Pos_653_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_8
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_ESEFVYGDY_Pos_1004_ID_S--pyogenes-Cas9_Allele_HLA-A0101_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_NLDKVLSAY_Pos_1285_ID_S--pyogenes-Cas9_Allele_HLA-A0101_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_GLDIGTNSV_Pos_7_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_GLFGNLIAL_Pos_235_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_NLIALSLGL_Pos_239_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_ILLSDILRV_Pos_299_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LTFRIPYYV_Pos_443_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SLLYEYFTV_Pos_511_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SLHEHIANL_Pos_718_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YLASHYEKL_Pos_1236_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YLDEIIEQI_Pos_1264_ID_S--pyogenes-Cas9_Allele_HLA-A0201_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AILSARLSK_Pos_209_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KTNRKVTVK_Pos_553_ID_S--pyogenes-Cas9_Allele_HLA-A0301_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AYHEKYPTI_Pos_126_ID_S--pyogenes-Cas9_Allele_HLA-A2402_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_IYLALAHMI_Pos_153_ID_S--pyogenes-Cas9_Allele_HLA-A2402_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_FYSNIMNFF_Pos_1037_ID_S--pyogenes-Cas9_Allele_HLA-A2402_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_EVVKKMKNY_Pos_873_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_FVYGDYKVY_Pos_1007_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_EIIEQISEF_Pos_1267_ID_S--pyogenes-Cas9_Allele_HLA-A2601_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_VPSKKFKVL_Pos_26_ID_S--pyogenes-Cas9_Allele_HLA-B0702_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SPAIKKGIL_Pos_729_ID_S--pyogenes-Cas9_Allele_HLA-B0702_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SPTVAYSVL_Pos_1135_ID_S--pyogenes-Cas9_Allele_HLA-B0702_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LPKYSLFEL_Pos_1197_ID_S--pyogenes-Cas9_Allele_HLA-B0702_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_VPSKKFKVL_Pos_26_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_MIKFRGHFL_Pos_160_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_QLKRRRYTG_Pos_649_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_FANRNFMQL_Pos_687_ID_S--pyogenes-Cas9_Allele_HLA-B0801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_HMIKFRGHF_Pos_159_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LLYEYFTVY_Pos_512_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_LIHDDSLTF_Pos_695_ID_S--pyogenes-Cas9_Allele_HLA-B1501_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRYTRRKNR_Pos_69_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRKNRICYL_Pos_73_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SRFAWMTRK_Pos_459_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRRYTGWGR_Pos_652_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_RRYTGWGRL_Pos_653_ID_S--pyogenes-Cas9_Allele_HLA-B2705_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_MKNYWRQLL_Pos_878_ID_S--pyogenes-Cas9_Allele_HLA-B3901_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_YHHAHDAYL_Pos_980_ID_S--pyogenes-Cas9_Allele_HLA-B3901_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AHDAYLNAV_Pos_983_ID_S--pyogenes-Cas9_Allele_HLA-B3901_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_GETAEATRL_Pos_55_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_VEDRFNASL_Pos_582_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_AERGGLSEL_Pos_902_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_GELQKGNEL_Pos_1217_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_SEFSKRVIL_Pos_1273_ID_S--pyogenes-Cas9_Allele_HLA-B4001_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KSEETITPW_Pos_467_ID_S--pyogenes-Cas9_Allele_HLA-B5801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KATAKYFFY_Pos_1030_ID_S--pyogenes-Cas9_Allele_HLA-B5801_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/mhc_preds__swap_KSVKELLGI_Pos_1157_ID_S--pyogenes-Cas9_Allele_HLA-B5801_nmer_9

# %% [markdown]
# ## Load file

# %%
from nepitope import mhc_utils
import pandas
import glob
import importlib
importlib.reload(mhc_utils)

#files saved from netMHC in  multiple different files, one per each query (nmer, allele)
filepath = '/Users/carlomazzaferro/Desktop/New_General/swaps/S__pyogenes_Cas9/preds_per_swap/'
fasta_file = '/Users/carlomazzaferro/Desktop/New_General/fasta_base_new_prots.fasta'

aggregate_all = mhc_utils.FileConsolidation(filepath, fasta_file)

# %%
#returns a dataframe per file used (just one in this case)
df_list = aggregate_all.return_df_list()

# %%
#Would run this. But too slow. The 3 cells below are speed-optimized. 
lsss_1 = aggregate_all.optimized_list_df_by_prot(df_list)

# %%
sss = pandas.concat(lsss_1)
high_int_aa = sss.loc[sss['Affinity Level'] ==  ('High' or 'Intermediate')]
high_int_aa.to_csv('/Users/carlomazzaferro/Desktop/Test_Workflow_From_Scratch/all_high_aff_aas.csv')

# %% [markdown]
# ## Load original proteins

# %%
from nepitope import pairwise_comp
importlib.reload(pairwise_comp)
# Out:
# <module 'nepitope.pairwise_comp' from '/Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/pairwise_comp.py'>

# %%
pwcomp = pairwise_comp.PairwiseComp(lsss_1, 5, fasta_file) 
df_pairwise_comps  = pwcomp.pipe_run()
# Out:
# /Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/pairwise_comp.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['Peptide'] = df['Peptide'].str.replace('X', '-')

# %%
swaps_df_dir = '/Users/carlomazzaferro/Desktop/Test_IEDB/OtherProtsPrashant/swap_results/S__pyogenes_Cas9/summary_results_per_prediction.csv'
swaps_df = pandas.read_csv(swaps_df_dir)

# %%
from importlib import reload
reload(merge_workflows)
from nepitope import merge_workflows
merged = merge_workflows.MergeSwapsAndComp(df_pairwise_comps, swaps_df, 40)
# Out:
# /Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/merge_workflows.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df = pandas.DataFrame(maximal_list)

# %%
merged.top_loc_matches[0:20]
for i in merged.top_loc_matches[0:20]:
    print('%i matches occurring at position %i' %(i[1], i[0]))
# Out:
# 130 matches occurring at position 657
# 129 matches occurring at position 447
# 126 matches occurring at position 656
# 124 matches occurring at position 446
# 122 matches occurring at position 658
# 119 matches occurring at position 448
# 117 matches occurring at position 813
# 115 matches occurring at position 814
# 110 matches occurring at position 659
# 109 matches occurring at position 445
# 109 matches occurring at position 812
# 106 matches occurring at position 514
# 106 matches occurring at position 655
# 103 matches occurring at position 513
# 100 matches occurring at position 449
# 98 matches occurring at position 512
# 98 matches occurring at position 515
# 98 matches occurring at position 985
# 98 matches occurring at position 987
# 96 matches occurring at position 986

# %%
df_top = merged.top_swap_df
df_ordered_filtered = merged.final_sort_and_filtering(df_top)
# Out:
# /Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/merge_workflows.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_ordered_filtered.columns
# Out:
# Index(['Unnamed: 0', 'nmer', 'allele', 'num high affinity peps',
#        'num med affinity peps', 'num low affinity peps',
#        'num no affinity peps', 'original peptide', 'original pos',
#        'top scoring peptides', 'Range'],
#       dtype='object')

# %%
reload(modify_data)
from nepitope import modify_data
mod_fasta = '/Users/carlomazzaferro/Desktop/PROJECT_LOC_TEST/mod_fastas/mod_all_fastas/'
orig_fasta = '/Users/carlomazzaferro/Desktop/PROJECT_LOC_TEST/prots_in_fasta.fasta'

mod_data = modify_data.ModifyData(swaps_df, fasta_file, mod_fasta, lsss_1)

# %%
######## TO INCLUDE IN TEST SUITE ########

from nepitope import pep_utils
j,k = pep_utils.create_separate_lists(fasta_file)
for i in sgl:
    print(i[1] in k[0])

for i in mod_data.swaps_dic.keys():
    print(i in mod_data.fasta_dic[0][1])
    print(i)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# RRYTRRKNR
# True
# KAILSARLSK
# True
# KLNREDLLRK
# True
# WRQLLNAKLI
# True
# SRFAWMTRK
# True
# LIHDDSLTF
# True
# IYLALAHMI
# True
# YHHAHDAYL
# True
# SLLYEYFTVY
# True
# ILLSDILRV
# True
# MLASAGELQK
# True
# KQSGKTILDF
# True
# RRLENLIAQL
# True
# KTYAHLFDDK
# True
# AHMIKFRGHF
# True
# LPKYSLFEL
# True
# SLHEHIANL
# True
# SPAIKKGIL
# True
# RLIYLALAHM
# True
# HYLDEIIEQI
# True
# RRKNRICYL
# True
# REQAENIIHL
# True
# KVLPKHSLLY
# True
# MIKFRGHFL
# True
# LLYEYFTVY
# True
# ALSLGLTPNF
# True
# NGLFGNLIAL
# True
# RRYTGWGRLS
# True
# LLYEYFTV
# True
# AHDAYLNAV
# True
# YLQNGRDMYV
# True
# TIMERSSFEK
# True
# RRYTRRKNRI
# True
# ILTFRIPYYV
# True
# RRRYTGWGR
# True
# SEFSKRVIL
# True
# GLDIGTNSV
# True
# MKNYWRQLL
# True
# RRRYTGWGRL
# True
# VEDRFNASL
# True
# FVYGDYKVY
# True
# SPTVAYSVL
# True
# IPHQIHLGEL
# True
# AYHEKYPTI
# True
# FANRNFMQL
# True
# KLPKYSLFEL
# True
# LTFRIPYYV
# True
# AENIIHLFTL
# True
# AILSARLSK
# True
# HMIKFRGHF
# True
# NSRFAWMTRK
# True
# EIIEQISEF
# True
# NLIALSLGL
# True
# FLYLASHYEK
# True
# AERGGLSEL
# True
# GVEDRFNASL
# True
# DEIIEQISEF
# True
# GELQKGNEL
# True
# EEVVKKMKNY
# True
# YLDEIIEQI
# True
# GLFGNLIAL
# True
# YEYFTVYNEL
# True
# VPSKKFKVL
# True
# EFVYGDYKVY
# True
# RRLENLIAQLP
# True
# RRQEDFYPFL
# True
# QLKRRRYTG
# True
# KSVKELLGI
# True
# SRFAWMTRKS
# True
# LQNEKLYLYY
# True
# LESEFVYGDY
# True
# RRYTGWGRL
# True
# MIKFRGHF
# True
# KTNRKVTVK
# True
# FYSNIMNFF
# True
# GETAEATRL
# True
# KVYDVRKMIAK
# True
# KRMLASAGEL
# True
# VSDFRKDFQFY
# True
# EIIEQISEFS
# True
# HSLLYEYFTV
# True
# YLASHYEKL
# True
# RRYTGWGR
# True
# SLLYEYFTV
# True
# TNLGAPAAFK
# True
# QLIHDDSLTF
# True
# KSEETITPW
# True
# NLDKVLSAY
# True
# KATAKYFFY
# True
# ESEFVYGDY
# True
# EVVKKMKNY
# True
# YLNAVVGTAL
# True
# SLGTYHDLLK
# True
# LIHQSITGLY
# True
# HMIKFRGHFL
# True
# KLFIQLVQTY
# True
# AILLSDILRV

# %%
mod_data.get_modified_fastas_single_swap()

# %%
exchange_pairs = []
for i,j in mod_data.swaps_dic.items():
    exchange_pairs.append([i,j])

# %%
import random

def get_all_exchange_pairs(swaps_df):
    cols = ['original peptide', 'top scoring peptides']
    sliced = swaps_df.ix[:, cols].values.tolist()
    orig = [i[0] for i in sliced]
    swaps = [list(filter(None, re.sub('[^A-Za-z0-9]+', ',', i[1]).split(','))) for i in sliced]
    hashmap = [[orig[i], swaps[i]] for i in range(len(orig))]
    swaps_single = []
    for idx, hsh in enumerate(hashmap):
        swaps_single.append([hsh[0], random.choice(hsh[1])])
    return swaps_single

sgl = get_all_exchange_pairs(swaps_df)

# %%
import os
fastas = glob.glob(mod_fasta + '*')
csv_path = '/Users/carlomazzaferro/Desktop/PROJECT_LOC_TEST/mod_csvs/mod_csvs_all_peps/'

list_dfs = []
for pair in exchange_pairs:
    for fasta in fastas:
        if os.path.splitext(os.path.basename(fasta))[0].split('-')[0] == pair[0]:
            my_fasta = fasta
            ls_mod = mod_data.get_singly_modified_df_list(pair[0], pair[1])
            pwcomp_pair_swap = pairwise_comp.PairwiseComp(ls_mod, 5, my_fasta)
            df_swap = pwcomp_pair_swap.pipe_run()
            df_swap = df_swap.drop('Matches Loc', 1)
            df_swap.to_csv(csv_path + pair[0] + '-' + pair[1] + '.csv')
            list_dfs.append(df_swap)
# Out:
# /Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/pairwise_comp.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['Peptide'] = df['Peptide'].str.replace('X', '-')

# %%
list_dfs[97].loc['S__pyogenes_Cas9']
# Out:
#                                   10   11    5    6   7   8   9 Num High AA  \
# C__jejuni_Cas9                     0    0    0    0   0   0   0           0
# Campylobacter_lari_Cas9            0    0    0    0   0   0   0           0
# Corynebacter_diphtheria_Cas9       0    0    0    0   0   0   0           0
# F__novicida_Cas9                   0    0    0    0   0   0   0           0
# Lactobacillus_buchneri_Cas9        0    0   15    5   2   1   0           2
# Listeria_innocua_Cas9              0    0   67   41  23  13   5           7
# N__meningitidis_Cas9               0    0    2    0   0   0   0           0
# Neisseria_cinerea_Cas9             0    0    2    0   0   0   0           0
# P__multocida_Cas9                  0    0    2    1   0   0   0           0
# Parvibaculum_lavamentivorans_Cas9  0    0    0    0   0   0   0           0
# S_CRISPR_1_thermophilus_Cas9       0    0    1    0   0   0   0           0
# S_CRISPR_3_thermophilus_Cas9       2    0  169  101  59  30  13          70
# S__mutans_Cas9                     1    0  128   88  56  30  13          87
# S__pyogenes_Cas9                   0  NaN   27   20  13   6   2          68
# Staphylococcus_aureus_Cas9         0    0    6    0   0   0   0           0
# Streptococcus_pasteurianus_Cas9    0    0    2    0   0   0   0           0
# T__denticola_Cas9                  0    0   27   12   2   1   0           1
#
#                                   Total
# C__jejuni_Cas9                        0
# Campylobacter_lari_Cas9               0
# Corynebacter_diphtheria_Cas9          0
# F__novicida_Cas9                      0
# Lactobacillus_buchneri_Cas9          23
# Listeria_innocua_Cas9               149
# N__meningitidis_Cas9                  2
# Neisseria_cinerea_Cas9                2
# P__multocida_Cas9                     3
# Parvibaculum_lavamentivorans_Cas9     0
# S_CRISPR_1_thermophilus_Cas9          1
# S_CRISPR_3_thermophilus_Cas9        374
# S__mutans_Cas9                      316
# S__pyogenes_Cas9                     68
# Staphylococcus_aureus_Cas9            6
# Streptococcus_pasteurianus_Cas9       2
# T__denticola_Cas9                    42

# %%
list_dfs[74].loc['S__pyogenes_Cas9']
# Out:
#                                    10   11    5    6   7   8   9 Num High AA  \
# C__jejuni_Cas9                      0    0    0    0   0   0   0           0
# Campylobacter_lari_Cas9             0    0    0    0   0   0   0           0
# Corynebacter_diphtheria_Cas9        0    0    0    0   0   0   0           0
# F__novicida_Cas9                    0    0    0    0   0   0   0           0
# Lactobacillus_buchneri_Cas9         0    0   15    5   2   1   0           4
# Listeria_innocua_Cas9               0    0   67   41  23  13   5           8
# N__meningitidis_Cas9                0    0    2    0   0   0   0           0
# Neisseria_cinerea_Cas9              0    0    2    0   0   0   0           0
# P__multocida_Cas9                   0    0    2    1   0   0   0           0
# Parvibaculum_lavamentivorans_Cas9   0    0    0    0   0   0   0           0
# S_CRISPR_1_thermophilus_Cas9        0    0    1    0   0   0   0           0
# S_CRISPR_3_thermophilus_Cas9        2    0  170  101  59  30  13          86
# S__mutans_Cas9                      2    0  131   91  59  33  15         124
# S__pyogenes_Cas9                   10  NaN  130  104  79  54  31         408
# Staphylococcus_aureus_Cas9          0    0    6    0   0   0   0           0
# Streptococcus_pasteurianus_Cas9     0    0    2    0   0   0   0           1
# T__denticola_Cas9                   0    0   27   12   2   1   0           3
#
#                                   Total
# C__jejuni_Cas9                        0
# Campylobacter_lari_Cas9               0
# Corynebacter_diphtheria_Cas9          0
# F__novicida_Cas9                      0
# Lactobacillus_buchneri_Cas9          23
# Listeria_innocua_Cas9               149
# N__meningitidis_Cas9                  2
# Neisseria_cinerea_Cas9                2
# P__multocida_Cas9                     3
# Parvibaculum_lavamentivorans_Cas9     0
# S_CRISPR_1_thermophilus_Cas9          1
# S_CRISPR_3_thermophilus_Cas9        375
# S__mutans_Cas9                      331
# S__pyogenes_Cas9                    408
# Staphylococcus_aureus_Cas9            6
# Streptococcus_pasteurianus_Cas9       2
# T__denticola_Cas9                    42

# %%
pwcomp_1_swap = pairwise_comp.PairwiseComp(ls_mod, 5, mod_fasta)
# Out:
# /Users/carlomazzaferro/Documents/Code/neoantigen/antigen_discovery/nepitope/pairwise_comp.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df['Peptide'] = df['Peptide'].str.replace('X', '-')

# %%
df_1_swap = pwcomp_1_swap.pipe_run()

# %%
df_1_swap.to_csv('/Users/carlomazzaferro/Desktop/Test_IEDB/OtherProtsPrashant/single_swap_pairwise_comp.csv')

# %%
df_1_swap.loc['S__pyogenes_Cas9']
# Out:
#                                    10 11    5    6    7    8    9  \
# C__jejuni_Cas9                      0  0    0    0    0    0    0
# Campylobacter_lari_Cas9             0  0    0    0    0    0    0
# Corynebacter_diphtheria_Cas9        0  0    0    0    0    0    0
# F__novicida_Cas9                    0  0    0    0    0    0    0
# Lactobacillus_buchneri_Cas9         0  0   13    5    2    1    0
# Listeria_innocua_Cas9               0  0   66   40   23   13    5
# N__meningitidis_Cas9                0  0    2    0    0    0    0
# Neisseria_cinerea_Cas9              0  0    2    0    0    0    0
# P__multocida_Cas9                   0  0    2    1    0    0    0
# Parvibaculum_lavamentivorans_Cas9   0  0    0    0    0    0    0
# S__mutans_Cas9                      1  0  119   81   49   24   10
# S__pyogenes_Cas9                   48  3  513  415  320  227  136
# S__thermophilus_CRISPR_3_Cas9       0  0  160   93   52   23    8
# Staphylococcus_aureus_Cas9          0  0    6    0    0    0    0
# Streptococcus_pasteurianus_Cas9     0  0    2    0    0    0    0
# T__denticola_Cas9                   0  0   27   12    2    1    0
#
#                                                                          Matches Loc  \
# C__jejuni_Cas9                                                                  [[]]
# Campylobacter_lari_Cas9                                                         [[]]
# Corynebacter_diphtheria_Cas9                                                    [[]]
# F__novicida_Cas9                                                                [[]]
# Lactobacillus_buchneri_Cas9        [[[1266, 1267, 1268, 1269, 1270], [1266, 1267,...
# Listeria_innocua_Cas9              [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# N__meningitidis_Cas9                        [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11]]]
# Neisseria_cinerea_Cas9                      [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11]]]
# P__multocida_Cas9                                                               [[]]
# Parvibaculum_lavamentivorans_Cas9                                               [[]]
# S__mutans_Cas9                     [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# S__pyogenes_Cas9                   [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# S__thermophilus_CRISPR_3_Cas9      [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# Staphylococcus_aureus_Cas9         [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11], [650, ...
# Streptococcus_pasteurianus_Cas9    [[[7, 8, 9, 10, 11], [1270, 1271, 1272, 1273, ...
# T__denticola_Cas9                  [[[164, 165, 166, 167, 168], [810, 811, 812, 8...
#
#                                   Num High AA Total
# C__jejuni_Cas9                              0     0
# Campylobacter_lari_Cas9                     0     0
# Corynebacter_diphtheria_Cas9                0     0
# F__novicida_Cas9                            0     0
# Lactobacillus_buchneri_Cas9                 5    21
# Listeria_innocua_Cas9                     118   147
# N__meningitidis_Cas9                        2     2
# Neisseria_cinerea_Cas9                      2     2
# P__multocida_Cas9                           0     3
# Parvibaculum_lavamentivorans_Cas9           0     0
# S__mutans_Cas9                            202   284
# S__pyogenes_Cas9                         1659  1662
# S__thermophilus_CRISPR_3_Cas9             210   336
# Staphylococcus_aureus_Cas9                  6     6
# Streptococcus_pasteurianus_Cas9             2     2
# T__denticola_Cas9                          41    42

# %%
df_pairwise_comps.loc['S__pyogenes_Cas9']
# Out:
#                                    10 11    5    6    7    8    9  \
# C__jejuni_Cas9                      0  0    0    0    0    0    0
# Campylobacter_lari_Cas9             0  0    0    0    0    0    0
# Corynebacter_diphtheria_Cas9        0  0    0    0    0    0    0
# F__novicida_Cas9                    0  0    0    0    0    0    0
# Lactobacillus_buchneri_Cas9         0  0   15    5    2    1    0
# Listeria_innocua_Cas9               0  0   67   41   23   13    5
# N__meningitidis_Cas9                0  0    2    0    0    0    0
# Neisseria_cinerea_Cas9              0  0    2    0    0    0    0
# P__multocida_Cas9                   0  0    2    1    0    0    0
# Parvibaculum_lavamentivorans_Cas9   0  0    0    0    0    0    0
# S__mutans_Cas9                      2  0  131   91   59   33   15
# S__pyogenes_Cas9                   52  3  542  441  343  245  147
# S__thermophilus_CRISPR_3_Cas9       2  0  171  101   59   30   13
# Staphylococcus_aureus_Cas9          0  0    6    0    0    0    0
# Streptococcus_pasteurianus_Cas9     0  0    2    0    0    0    0
# T__denticola_Cas9                   0  0   27   12    2    1    0
#
#                                                                          Matches Loc  \
# C__jejuni_Cas9                                                                  [[]]
# Campylobacter_lari_Cas9                                                         [[]]
# Corynebacter_diphtheria_Cas9                                                    [[]]
# F__novicida_Cas9                                                                [[]]
# Lactobacillus_buchneri_Cas9        [[[1266, 1267, 1268, 1269, 1270], [1266, 1267,...
# Listeria_innocua_Cas9              [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# N__meningitidis_Cas9                        [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11]]]
# Neisseria_cinerea_Cas9                      [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11]]]
# P__multocida_Cas9                                                               [[]]
# Parvibaculum_lavamentivorans_Cas9                                               [[]]
# S__mutans_Cas9                     [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# S__pyogenes_Cas9                   [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# S__thermophilus_CRISPR_3_Cas9      [[[8, 9, 10, 11, 12, 13, 14, 15], [7, 8, 9, 10...
# Staphylococcus_aureus_Cas9         [[[7, 8, 9, 10, 11], [7, 8, 9, 10, 11], [650, ...
# Streptococcus_pasteurianus_Cas9    [[[7, 8, 9, 10, 11], [1270, 1271, 1272, 1273, ...
# T__denticola_Cas9                  [[[164, 165, 166, 167, 168], [810, 811, 812, 8...
#
#                                   Num High AA Total
# C__jejuni_Cas9                              0     0
# Campylobacter_lari_Cas9                     0     0
# Corynebacter_diphtheria_Cas9                0     0
# F__novicida_Cas9                            0     0
# Lactobacillus_buchneri_Cas9                 7    23
# Listeria_innocua_Cas9                     120   149
# N__meningitidis_Cas9                        2     2
# Neisseria_cinerea_Cas9                      2     2
# P__multocida_Cas9                           0     3
# Parvibaculum_lavamentivorans_Cas9           0     0
# S__mutans_Cas9                            249   331
# S__pyogenes_Cas9                         1770  1773
# S__thermophilus_CRISPR_3_Cas9             250   376
# Staphylococcus_aureus_Cas9                  6     6
# Streptococcus_pasteurianus_Cas9             2     2
# T__denticola_Cas9                          41    42
