# %% [markdown]
# # Conservation Analysis and Epitope Prediction
#
#
# #### Author: C. Mazzaferro, K. Fisch
# #### Email: cmazzafe@ucsd.edu
# #### Date: August 2016
#
# ## Outline of Notebook
# <a id = "toc"></a>
# 1. <a href = "#background">Background</a>
# 2. <a href = "#ConsA">Conservation Analysis</a>
#     * <a href = "#BLAST">BLAST-P</a>
#     * <a href = "#MSA">Multiple Sequence Alignment</a>
#     * <a href = "#Cons">Conservation Score Prediction</a>
# 3. <a href = "#ep_pred">Windowing and New Epitope Prediction</a>
#     * <a href = "#clustering">Epitope Clustering Analysis</a>

# %% [markdown]
# This workflow aims at finding peptide substitute candidates by swapping 1 AA at a time from a prioritized list of peptides. This prioritized list was found using the workflow - Base Workflow.

# %% [markdown]
# ## Finding similar peptides by doing simple AA swaps
# The peptides will be written to a fasta file which will be sent to netMHCcons. Results will be analyzed subsequentially

# %%
import pandas

csv_path = '/Users/carlomazzaferro/Desktop/Test_Workflow_From_Scratch/all_high_aff_aas.csv'
high_aa_df = pandas.read_csv(csv_path)

# %%
from nepitope import pep_utils
fasta_files_dir = '/Users/carlomazzaferro/Desktop/Test_Workflow_From_Scratch/swaps/'
pep_utils.find_swaps_write_to_fasta(high_aa_df, fasta_files_dir)

# %%
import importlib
from nepitope import net_MHC_interface
importlib.reload(net_MHC_interface)



fasta_file = '/Users/carlomazzaferro/Desktop/PROJECT_LOC_TEST/prots_in_fasta.fasta'
net_mhc_path = '/Users/carlomazzaferro/Desktop/BINF_Tools/netMHC-4.0/netMHC'

# %%
import os

fasta_files = '/Users/carlomazzaferro/Desktop/Test_Workflow_From_Scratch/swaps/StreptococcusPyogenes_reference/'
fls = glob.glob(fasta_files + '*')
net_mhc_comm = []

for i in fls:
    base_name = os.path.basename(i).split('.')[0]
    dat = base_name.split('_')
    allele = dat[-3]
    nmer = int(dat[-1])        
    file_name_out =  base_name + '.csv'
    net_mhc_comm.append('%s -a %s -f %s -l %i -xls -xlsfile %s' % (net_mhc_path, allele, i,
                                                                              nmer, file_name_out))

# %%
net_mhc_cmd_str = fasta_files + 'Results/net_mhc_command.txt'
with open(net_mhc_cmd_str, 'w') as cmd:
    for i in net_mhc_comm:
        cmd.write(i + '\n')

# %% [markdown]
# ### Load Results From netMHC
# The swaps are sent to netMHCCons, and the results are aggragated under the class FileConsolidation in the module scoring_utils

# %%
from nepitope import mhc_utils, summary_data
import glob
nmers = [8, 9,10,11]

#files saved from netMHCcons as split_*i*_prediction_*n*_mer for each split/nmer
filepath = '/Users/carlomazzaferro/Desktop/Test_IEDB/newer_pipeline_files/consistent_aws_netMHC40/swaps/mhc_preds_per_swap/'
fasta_file = '/Users/carlomazzaferro/Desktop/Test_IEDB/newer_pipeline_files/fasta_from_study_dealigned.fasta'

file_pattern = '_swap_*'

aggregate_all = mhc_utils.FileConsolidation(filepath, fasta_file)

files = glob.glob(filepath + file_pattern)
original_peps_and_pos = []

for file in files:
    split_ = file.split('/')[-1]
    split_2 = split_.split('_')
    original_peps_and_pos.append([split_2[2], split_2[4]])

# %% [markdown]
# ### Return them in a list of dataframes
# summary_data is the module that performs all the data aggregation on newly found peptides.

# %%
list_results = aggregate_all.return_df_list()

# %%
summ_data = summary_data.SummaryData()
summ_data_analysis = summ_data.summarize_data_for_each_mhc_pred(list_results, original_peps_and_pos, high_aa_df)

# %%
pd = pandas.concat(summ_data_analysis.container)
cl = pd.drop_duplicates()
#cl.to_csv('/Users/carlomazzaferro/Desktop/all_preds_swaps.csv')

# %% [markdown]
# ### Return summary data in a dataframe
# Other methods and attributes are present as well

# %%
summ_data_analysis.summary_df['original peptide'].values.tolist()[0:20]
# Out:
# ['AENIIHLFTL',
#  'AERGGLSEL',
#  'AHDAYLNAV',
#  'AHMIKFRGHF',
#  'AILLSDILRV',
#  'AILSARLSK',
#  'ALSLGLTPNF',
#  'AYHEKYPTI',
#  'DEIIEQISEF',
#  'EEVVKKMKNY',
#  'EFVYGDYKVY',
#  'EIIEQISEF',
#  'EIIEQISEFS',
#  'ESEFVYGDY',
#  'EVVKKMKNY',
#  'FANRNFMQL',
#  'FLYLASHYEK',
#  'FVYGDYKVY',
#  'FYSNIMNFF',
#  'GELQKGNEL']

# %%
summ_data_analysis.summary_df.sort_values(by='original pos')
# Out:
#    nmer     allele num high affinity peps num med affinity peps  \
# 21    9  HLA-A0201                     74                    64
# 89    9  HLA-B0801                     57                    80
# 88    9  HLA-B0702                     94                    50
# 20    9  HLA-B4001                    129                    15
# 74    9  HLA-B2705                     88                    61
# 75   10  HLA-B2705                    145                    34
# 65    9  HLA-B2705                     70                    76
# 7     9  HLA-A2402                     83                    62
# 64   10  HLA-B1501                    144                    41
# 31    9  HLA-A2402                    121                    28
# 3    10  HLA-B1501                    149                    22
# 25   10  HLA-B0801                    107                    63
# 24    9  HLA-B1501                    137                    16
# 53    8  HLA-B0801                     50                    58
# 54    9  HLA-B0801                    124                    37
# 34   10  HLA-B1501                    150                    25
# 32   10  HLA-A0301                    121                    62
# 5     9  HLA-A0301                     91                    57
# 66   10  HLA-B2705                    160                    21
# 67   11  HLA-B2705                    102                    75
# 57   10  HLA-A0201                     71                    90
# 22    9  HLA-A0201                    125                    26
# 59    9  HLA-A0201                     75                    66
# 6    10  HLA-B1501                     89                    77
# 4    10  HLA-A0201                    116                    67
# 28    9  HLA-A0201                    143                    10
# 35   10  HLA-A0301                    105                    62
# 30   10  HLA-B0702                    102                    63
# 68   10  HLA-B2705                     88                    88
# 29   10  HLA-A0201                    166                    20
# ..  ...        ...                    ...                   ...
# 2     9  HLA-B3901                     73                    65
# 96   10  HLA-A0201                     82                    78
# 45   10  HLA-A0101                     99                    54
# 13    9  HLA-A0101                    110                    23
# 10   10  HLA-A2601                     86                    51
# 17    9  HLA-A2601                     84                    47
# 44   11  HLA-A0301                    105                    77
# 33    9  HLA-B5801                    106                    39
# 18    9  HLA-A2402                    115                    32
# 82    9  HLA-B0702                    118                    29
# 40    9  HLA-B5801                     75                    54
# 85   10  HLA-A0301                    128                    43
# 36   10  HLA-A0201                     95                    71
# 50    9  HLA-B0702                     72                    70
# 38   10  HLA-B2705                    123                    47
# 56   10  HLA-A0301                    120                    48
# 19    9  HLA-B4001                    104                    39
# 16   10  HLA-A0301                    141                    30
# 94    9  HLA-A0201                    106                    35
# 27   10  HLA-A0201                     93                    67
# 95    9  HLA-A0201                    142                    11
# 8    10  HLA-A2601                     82                    69
# 12   10  HLA-A2601                     79                    58
# 11    9  HLA-A2601                    142                    25
# 76    9  HLA-B4001                    120                    22
# 58    9  HLA-A0101                     90                    38
# 63   10  HLA-B4001                     86                    75
# 0    10  HLA-B4001                    155                     9
# 86   10  HLA-A0301                    114                    58
# 47   10  HLA-B1501                     87                    83
#
#    num low affinity peps num no affinity peps original peptide original pos  \
# 21                    14                   28        GLDIGTNSV            7
# 89                    38                    5        VPSKKFKVL           26
# 88                    11                   25        VPSKKFKVL           26
# 20                    15                   21        GETAEATRL           55
# 74                    16                   15        RRYTRRKNR           69
# 75                     6                   15       RRYTRRKNRI           69
# 65                    18                   15        RRKNRICYL           73
# 7                     15                   20        AYHEKYPTI          126
# 64                     9                    6       RLIYLALAHM          151
# 31                    25                    6        IYLALAHMI          153
# 3                     17                   12       AHMIKFRGHF          158
# 25                    24                    6       HMIKFRGHFL          159
# 24                    17                   10        HMIKFRGHF          159
# 53                    44                    8         MIKFRGHF          160
# 54                    19                    0        MIKFRGHFL          160
# 34                    16                    9       KLFIQLVQTY          182
# 32                     1                   16       KAILSARLSK          208
# 5                     14                   18        AILSARLSK          209
# 66                     6                   13       RRLENLIAQL          219
# 67                    24                   19      RRLENLIAQLP          219
# 57                    20                   19       NGLFGNLIAL          234
# 22                    18                   11        GLFGNLIAL          235
# 59                    15                   24        NLIALSLGL          239
# 6                     20                   14       ALSLGLTPNF          242
# 4                      6                   11       AILLSDILRV          298
# 28                    12                   15        ILLSDILRV          299
# 35                    14                   18       KLNREDLLRK          391
# 30                    10                   25       IPHQIHLGEL          409
# 68                     8                   16       RRQEDFYPFL          423
# 29                    10                    4       ILTFRIPYYV          442
# ..                   ...                  ...              ...          ...
# 2                     37                    5        AHDAYLNAV          983
# 96                    24                   15       YLNAVVGTAL          987
# 45                    18                   29       LESEFVYGDY         1003
# 13                    22                   25        ESEFVYGDY         1004
# 10                    47                   16       EFVYGDYKVY         1006
# 17                    24                   25        FVYGDYKVY         1007
# 44                    20                   18      KVYDVRKMIAK         1013
# 33                    27                    8        KATAKYFFY         1030
# 18                    17                   16        FYSNIMNFF         1037
# 82                    13                   20        SPTVAYSVL         1135
# 40                    30                   21        KSVKELLGI         1157
# 85                    13                   16       TIMERSSFEK         1166
# 36                    11                   23       KLPKYSLFEL         1196
# 50                    10                   27        LPKYSLFEL         1197
# 38                    13                   17       KRMLASAGEL         1210
# 56                    16                   16       MLASAGELQK         1212
# 19                    11                   26        GELQKGNEL         1217
# 16                    11                   18       FLYLASHYEK         1234
# 94                    12                   27        YLASHYEKL         1236
# 27                    18                   22       HYLDEIIEQI         1263
# 95                    16                   11        YLDEIIEQI         1264
# 8                     24                   25       DEIIEQISEF         1266
# 12                    44                   19       EIIEQISEFS         1267
# 11                    13                    0        EIIEQISEF         1267
# 76                    17                   21        SEFSKRVIL         1273
# 58                    14                   38        NLDKVLSAY         1285
# 63                    29                   10       REQAENIIHL         1302
# 0                     12                   24       AENIIHLFTL         1305
# 86                    12                   16       TNLGAPAAFK         1315
# 47                    12                   18       LIHQSITGLY         1346
#
#                                  top scoring peptides
# 21  [GLDIGTNSD, GHDIGTNSV, GRDIGTNSV, GDDIGTNSV, G...
# 89  [VPSKKFKVK, VPSKKFKVR, VPSKKFKVD, VPSKKFKVN, V...
# 88  [VDSKKFKVL, VCSKKFKVL, VWSKKFKVL, VESKKFKVL, V...
# 20  [GGTAEATRL, GPTAEATRL, GITAEATRL, GLTAEATRL, G...
# 74  [RDYTRRKNR, RPYTRRKNR, RCYTRRKNR, REYTRRKNR, R...
# 75  [RPYTRRKNRI, RDYTRRKNRI, RFYTRRKNRI, RGYTRRKNR...
# 65  [RDKNRICYL, RPKNRICYL, REKNRICYL, RGKNRICYL, R...
# 7   [APHEKYPTI, AEHEKYPTI, AKHEKYPTI, ADHEKYPTI, A...
# 64  [RLIYLALAHR, RLIYLALAHK, RLIYLALAHD, RLIYLALAH...
# 31  [IPLALAHMI, IELALAHMI, IDLALAHMI, IKLALAHMI, I...
# 3   [AHMIKFRGHD, AHMIKFRGHR, AHMIKFRGHN, AHMIKFRGH...
# 25  [HMIKFRGHFK, HMIKFRGHFR, HMIKFRGHFD, HMIKFRGHF...
# 24  [HMIKFRGHD, HMIKFRGHR, HMIKFRGHN, HMIKFRGHK, H...
# 53  [MIDFRGHF, MIKFPGHF, MIKFDGHF, PIKFRGHF, MIPFR...
# 54  [MIKFRGHFK, MIKFRGHFR, MIKFRGHFD, MIKFRGHFN, M...
# 34  [KLFIQLVQTD, KLFIQLVQTR, KLFIQLVQTN, KLFIQLVQT...
# 32  [KAILSARLSD, KAILSARLSG, KAILSARLSS, KAILSARLS...
# 5   [AILSARLSD, AILSARLSG, AILSARLSS, AILSARLST, A...
# 66  [RPLENLIAQL, RDLENLIAQL, RFLENLIAQL, RGLENLIAQ...
# 67  [RPLENLIAQLP, RDLENLIAQLP, RFLENLIAQLP, RGLENL...
# 57  [NGRFGNLIAL, NGHFGNLIAL, NGPFGNLIAL, NGDFGNLIA...
# 22  [GHFGNLIAL, GPFGNLIAL, GRFGNLIAL, GDFGNLIAL, G...
# 59  [NHIALSLGL, NDIALSLGL, NRIALSLGL, NPIALSLGL, N...
# 6   [ALSLGLTPND, ALSLGLTPNR, ALSLGLTPNN, ALSLGLTPN...
# 4   [AILLSDILRD, AILLSDILRE, AILLSDILRH, AILLSDILR...
# 28  [ILLSDILRD, ILLSDILRH, IHLSDILRV, IPLSDILRV, I...
# 35  [KLNREDLLRE, KLNREDLLRD, KLNREDLLRT, KLNREDLLR...
# 30  [IDHQIHLGEL, ICHQIHLGEL, IWHQIHLGEL, IEHQIHLGE...
# 68  [RPQEDFYPFL, RDQEDFYPFL, REQEDFYPFL, RGQEDFYPF...
# 29  [ILTFRIPYYD, ILTFRIPYYH, ILTFRIPYYE, ILTFRIPYY...
# ..                                                ...
# 2   [AWDAYLNAV, ADDAYLNAV, AFDAYLNAV, AGDAYLNAV, A...
# 96  [YHNAVVGTAL, YDNAVVGTAL, YPNAVVGTAL, YRNAVVGTA...
# 45  [LESEFVYGDD, LESEFVYGDE, LESEFVYGDP, LESEFVYGD...
# 13  [ESEFVYGDD, ESEFVYGDP, ESEFVYGDE, ESEFVYGDG, E...
# 10  [EFVYGDYKVN, EFVYGDYKVG, EFVYGDYKVD, EFVYGDYKV...
# 17  [FVYGDYKVN, FVYGDYKVG, FVYGDYKVD, FVYGDYKVK, F...
# 44  [KVYDVRKMIAG, KVYDVRKMIAD, KVYDVRKMIAT, KVYDVR...
# 33  [KDTAKYFFY, KATAKYFFR, DATAKYFFY, KETAKYFFY, K...
# 18  [FYSNIMNFK, FPSNIMNFF, FYSNIMNFE, FYSNIMNFS, F...
# 82  [SDTVAYSVL, SCTVAYSVL, SWTVAYSVL, SRTVAYSVL, S...
# 40  [KDVKELLGI, KEVKELLGI, KRVKELLGI, KPVKELLGI, K...
# 85  [TIMERSSFEG, TIMERSSFED, TIMERSSFES, TIMERSSFE...
# 36  [KHPKYSLFEL, KDPKYSLFEL, KRPKYSLFEL, KPPKYSLFE...
# 50  [LDKYSLFEL, LCKYSLFEL, LWKYSLFEL, LEKYSLFEL, L...
# 38  [KPMLASAGEL, KDMLASAGEL, KEMLASAGEL, KGMLASAGE...
# 56  [MLASAGELQD, MLASAGELQG, MLASAGELQS, MLASAGELQ...
# 19  [GGLQKGNEL, GPLQKGNEL, GILQKGNEL, GRLQKGNEL, G...
# 16  [FLYLASHYEG, FLYLASHYED, FLYLASHYES, FLYLASHYE...
# 94  [YHASHYEKL, YRASHYEKL, YDASHYEKL, YPASHYEKL, Y...
# 27  [HYHDEIIEQI, HYPDEIIEQI, HYRDEIIEQI, HYDDEIIEQ...
# 95  [YHDEIIEQI, YPDEIIEQI, YRDEIIEQI, YDDEIIEQI, Y...
# 8   [DEIIEQISEN, DEIIEQISEG, DEIIEQISED, DEIIEQISE...
# 12  [KIIEQISEFS, RIIEQISEFS, ERIEQISEFS, EKIEQISEF...
# 11  [KIIEQISEF, EIIEQISEN, RIIEQISEF, EIIEQISEG, E...
# 76  [SPFSKRVIL, SGFSKRVIL, SIFSKRVIL, SLFSKRVIL, S...
# 58  [NLDKVLSAD, NLDKVLSAP, NLDKVLSAE, NLDKVLSAG, N...
# 63  [REQAENIIHG, REQAENIIHS, REQAENIIHW, REQAENIIH...
# 0   [AINIIHLFTL, APNIIHLFTL, AGNIIHLFTL, ANNIIHLFT...
# 86  [TNLGAPAAFD, TNLGAPAAFG, TNLGAPAAFS, TNLGAPAAF...
# 47  [LIHQSITGLD, LIHQSITGLT, LIHQSITGLR, LIHQSITGL...
#
# [98 rows x 9 columns]

# %% [markdown]
# ### Write files out

# %%
fasta_dir = '/Users/carlomazzaferro/Desktop/fasta_swaps_top_20_percent.fasta'
summ_data_analysis.write_peptides_to_fasta(fasta_dir)

# %%
csv_path = '/Users/carlomazzaferro/Desktop/Test_IEDB/newer_pipeline_files/consistent_aws_netMHC40/summary_results_per_prediction.csv'
summ_data_analysis.summary_df.sort_values(by='original pos').to_csv(path_or_buf=csv_path, sep=',')

# %%
basepath = '/Users/carlomazzaferro/Desktop/Test_IEDB/newer_pipeline_files/consistent_aws_netMHC40/csv_for_each_pred/'
for idx, val in enumerate(list_results):
    original_pep = original_peps_and_pos[idx][0]
    pos = original_peps_and_pos[idx][1]
    allele = val.Allele.unique()[0]
    nmer = val['n-mer'].unique()[0]
    name = "_".join([original_pep, pos, allele, str(nmer)])
    val['Peptide'] = val['Peptide'].str.replace('X', '-')
    write_to_csv(val, basepath + name + '.csv')

# %%
def write_to_csv(df, path_name):
    df.to_csv(path_name, sep=',')
