# %%
import glob
import sys
sys.path.append('/Users/carlomazzaferro/Documents/Code/neoantigen/')
from mhc_parser import models, methods, utilities
import importlib
importlib.reload(models)


files = glob.glob('/Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/*.xls')
fasta_file = '/Users/carlomazzaferro/Desktop/New_General/MICE/fasta_base_new_prots.fasta'
pred_col = models.PredictionCollection(files, fasta_file)

# %%
parsing = pred_col.digest_multiple()
# Out:
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Db_10.xls 0
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Db_11.xls 1
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Db_8.xls 2
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Db_9.xls 3
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Dd_10.xls 4
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Dd_11.xls 5
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Dd_8.xls 6
# /Users/carlomazzaferro/Desktop/New_General/MICE/mhc_preds_fasta_base_new_prots/fasta_base_new_prots_H-2-Dd_9.xls 7
# ...

# %%
pred_col.dictionary_collection.keys()
# Out:
# dict_keys(['P__multocida_Ca', 'S__mutans_Cas9', 'T__denticola_Ca', 'Parvibaculum_la', 'S_CRISPR_3_ther', 'Staphylococcus_', 'Lactobacillus_b', 'Streptococcus_p', 'Campylobacter_l', 'N__meningitidis', 'S__pyogenes_Cas', 'Neisseria_ciner', 'Listeria_innocu', 'S_CRISPR_1_ther', 'Corynebacter_di', 'F__novicida_Cas', 'C__jejuni_Cas9'])

# %%
pred_col.dictionary_collection['S__mutans_Cas9']

# %%
filt = pred_col.filter_low_aff(ref, 50)

# %%
filt[0].Swap.swaps
# Out:
# ['AANRNFMQL',
#  'RANRNFMQL',
#  'NANRNFMQL',
#  'DANRNFMQL',
#  'CANRNFMQL',
#  'QANRNFMQL',
#  'EANRNFMQL',
#  'GANRNFMQL',
#  'HANRNFMQL',
#  'IANRNFMQL',
#  'LANRNFMQL',
#  'KANRNFMQL',
#  'MANRNFMQL',
#  'PANRNFMQL',
#  'SANRNFMQL',
#  'TANRNFMQL',
#  'WANRNFMQL',
#  'YANRNFMQL',
#  'VANRNFMQL',
#  'FRNRNFMQL',
#  'FNNRNFMQL',
#  'FDNRNFMQL',
#  'FCNRNFMQL',
#  'FQNRNFMQL',
#  'FENRNFMQL',
#  'FGNRNFMQL',
#  'FHNRNFMQL',
#  'FINRNFMQL',
#  'FLNRNFMQL',
#  'FKNRNFMQL',
#  'FMNRNFMQL',
#  'FFNRNFMQL',
#  'FPNRNFMQL',
#  'FSNRNFMQL',
#  'FTNRNFMQL',
#  'FWNRNFMQL',
#  'FYNRNFMQL',
#  'FVNRNFMQL',
#  'FAARNFMQL',
#  'FARRNFMQL',
#  'FADRNFMQL',
#  'FACRNFMQL',
#  'FAQRNFMQL',
#  'FAERNFMQL',
#  'FAGRNFMQL',
#  'FAHRNFMQL',
#  'FAIRNFMQL',
#  'FALRNFMQL',
#  'FAKRNFMQL',
#  'FAMRNFMQL',
#  'FAFRNFMQL',
#  'FAPRNFMQL',
#  'FASRNFMQL',
#  'FATRNFMQL',
#  'FAWRNFMQL',
#  'FAYRNFMQL',
#  'FAVRNFMQL',
#  'FANANFMQL',
#  'FANNNFMQL',
#  'FANDNFMQL',
#  'FANCNFMQL',
#  'FANQNFMQL',
# ...

# %%
ls = pred_col.return_protein_df_list()

# %%
ls[0]
# Out:
#         Pos     Peptide          Protein Affinity_level    rank   core_pep  \
# 0         0  MDKKYSIGLD  S__pyogenes_Cas        48949.2  99.000  MKKYSIGLD
# 1         1  DKKYSIGLDI  S__pyogenes_Cas        43102.3  40.000  KKYSIGLDI
# 2         2  KKYSIGLDIG  S__pyogenes_Cas        43368.0  41.000  KKYIGLDIG
# 3         3  KYSIGLDIGT  S__pyogenes_Cas        46059.0  60.000  YSIGLDIGT
# 4         4  YSIGLDIGTN  S__pyogenes_Cas        33732.9  18.000  YSILDIGTN
# 5         5  SIGLDIGTNS  S__pyogenes_Cas        46216.2  60.000  SIGLDIGTS
# 6         6  IGLDIGTNSV  S__pyogenes_Cas        28043.6  12.000  IGLIGTNSV
# 7         7  GLDIGTNSVG  S__pyogenes_Cas        47732.2  80.000  GLDIGTNSV
# 8         8  LDIGTNSVGW  S__pyogenes_Cas        46710.9  65.000  LDITNSVGW
# 9         9  DIGTNSVGWA  S__pyogenes_Cas        43384.9  41.000  DIGTNSVWA
# 10       10  IGTNSVGWAV  S__pyogenes_Cas        37514.0  24.000  IGTNSGWAV
# ...

# %%
pred_col.dictionary_collection[ref][0].affinity_level
# Out:
# 48949.2

# %%
len(filt)
# Out:
# 40

# %%
net_mhc_path = '/Users/carlomazzaferro/Desktop/BINF_Tools/netMHC-4.0/netMHC'
pred_col.predict_swaps(ref, 50, net_mhc_path)
# Out:
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/MICE/temp/mhc_preds_S__pyogenes_Cas_swap_FANRNFMQL_Pos_687_ID_S--pyogenes-Cas_Allele_H-2-Db_nmer_9
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/MICE/temp/mhc_preds_S__pyogenes_Cas_swap_TAKYFFYSNI_Pos_1032_ID_S--pyogenes-Cas_Allele_H-2-Kb_nmer_10
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/MICE/temp/mhc_preds_S__pyogenes_Cas_swap_ATAKYFFYSNI_Pos_1031_ID_S--pyogenes-Cas_Allele_H-2-Kb_nmer_11
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/MICE/temp/mhc_preds_S__pyogenes_Cas_swap_TAKYFFYSNIM_Pos_1032_ID_S--pyogenes-Cas_Allele_H-2-Kb_nmer_11
# Predictions being saved to /Users/carlomazzaferro/Desktop/New_General/MICE/temp/mhc_preds_S__pyogenes_Cas_swap_ANRNFMQL_Pos_688_ID_S--pyogenes-Cas_Allele_H-2-Kb_nmer_8
# ...

# %%
ref = 'S__pyogenes_Cas'

pred_col.protein_dataframe(ref)
# Out:
#       Pos     Peptide          Protein Affinity_level    rank   core_pep  \
# 0       0  MDKKYSIGLD  S__pyogenes_Cas        48949.2  99.000  MKKYSIGLD
# 1       1  DKKYSIGLDI  S__pyogenes_Cas        43102.3  40.000  KKYSIGLDI
# 2       2  KKYSIGLDIG  S__pyogenes_Cas        43368.0  41.000  KKYIGLDIG
# 3       3  KYSIGLDIGT  S__pyogenes_Cas        46059.0  60.000  YSIGLDIGT
# 4       4  YSIGLDIGTN  S__pyogenes_Cas        33732.9  18.000  YSILDIGTN
# 5       5  SIGLDIGTNS  S__pyogenes_Cas        46216.2  60.000  SIGLDIGTS
# 6       6  IGLDIGTNSV  S__pyogenes_Cas        28043.6  12.000  IGLIGTNSV
# 7       7  GLDIGTNSVG  S__pyogenes_Cas        47732.2  80.000  GLDIGTNSV
# 8       8  LDIGTNSVGW  S__pyogenes_Cas        46710.9  65.000  LDITNSVGW
# 9       9  DIGTNSVGWA  S__pyogenes_Cas        43384.9  41.000  DIGTNSVWA
# 10     10  IGTNSVGWAV  S__pyogenes_Cas        37514.0  24.000  IGTNSGWAV
# 11     11  GTNSVGWAVI  S__pyogenes_Cas        26915.7  11.000  GTNVGWAVI
# ...
